# %%
import os
import glob
start_path = 'Plots'

f = os.walk(start_path) 

for root, dirs, files in os.walk(start_path):
    print(dirs)
    for d in dirs:
        print('LLL',d)
        for file in os.listdir(os.path.join(root,d)):
            if file.endswith(".pdf"):
                print(file)
                new_filename= file.replace(' ', '_')
                print(new_filename, '\n')
                os.rename(os.path.join(root,d,file), os.path.join(root,d,new_filename))

# for d in dirnames:
#     print(d)

            

# for dirpath, dirnames, filenames in os.walk(start_path):
#     for d in dirnames:
#         path = os.path.join(dirpath,d,'*.pdf')
#         # print(path)
#         pdfs = glob.glob(path)
#         #print(len(pdfs))
#         for filename in pdfs:
#             fp = os.path.join(filename)
#             print(fp)
#             new_filename = filename.replace(' ','_')
#             print(new_filename, '\n')
# Out:
# ['Chapter 0- Intro', 'Chapter 1- Island Analysis', 'Chapter 2- Group Analysis', 'Chapter 3- Cluster Analysis']
# LLL Chapter 0- Intro
# Operation_plot.pdf
# Operation_plot.pdf
#
# windfarms_on_map.pdf
# windfarms_on_map.pdf
#
# LLL Chapter 1- Island Analysis
# Average of all Windfarms in the last years.pdf
# Average_of_all_Windfarms_in_the_last_years.pdf
#
# Average_monthly_wind_power_of_each_windfarms_during_last_years_0.pdf
# Average_monthly_wind_power_of_each_windfarms_during_last_years_0.pdf
#
# Average_monthly_wind_power_of_each_windfarms_during_last_years_1.pdf
# Average_monthly_wind_power_of_each_windfarms_during_last_years_1.pdf
#
# Average_monthly_wind_power_of_each_windfarms_during_last_years_2.pdf
# Average_monthly_wind_power_of_each_windfarms_during_last_years_2.pdf
#
# Average_monthly_wind_power_of_each_windfarms_during_last_years_3.pdf
# Average_monthly_wind_power_of_each_windfarms_during_last_years_3.pdf
#
# ...
